# %% [markdown]
# Kaggle link: https://www.kaggle.com/code/lorenzozanolin/dog-vs-cats-zanolin
#
#
# W&B link: https://wandb.ai/lorenzozanolin-52/dogs_cats/table?workspace=user-lorenzozanolin-52

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/dogs-vs-cats-redux-kernels-edition/sample_submission.csv
# /kaggle/input/dogs-vs-cats-redux-kernels-edition/train.zip
# /kaggle/input/dogs-vs-cats-redux-kernels-edition/test.zip

# %% [markdown]
# ## Import everything needed

# %%
import zipfile
import glob
from PIL import Image
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
np.random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed(0)

import wandb
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("a")
wandb.login(key=secret_value_0)
wandb.init(project='dogs_cats', save_code=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: lorenzozanolin-52. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/kaggle/working/wandb/run-20240115_110924-100c4rzk</code>
# Syncing run <strong><a href='https://wandb.ai/lorenzozanolin-52/dogs_cats/runs/100c4rzk' target="_blank">peachy-dragon-13</a></strong> to <a href='https://wandb.ai/lorenzozanolin-52/dogs_cats' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/lorenzozanolin-52/dogs_cats' target="_blank">https://wandb.ai/lorenzozanolin-52/dogs_cats</a>
#  View run at <a href='https://wandb.ai/lorenzozanolin-52/dogs_cats/runs/100c4rzk' target="_blank">https://wandb.ai/lorenzozanolin-52/dogs_cats/runs/100c4rzk</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/lorenzozanolin-52/dogs_cats/runs/100c4rzk?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# ## Unzip datasets

# %%
train_dir = 'train'
test_dir = 'test'
with zipfile.ZipFile('/kaggle/input/dogs-vs-cats-redux-kernels-edition/train.zip') as train_zip:
    train_zip.extractall('')
    
with zipfile.ZipFile('/kaggle/input/dogs-vs-cats-redux-kernels-edition/test.zip') as test_zip:
    test_zip.extractall('')
train_list = glob.glob(os.path.join(train_dir,'*.jpg'))
test_list = glob.glob(os.path.join(test_dir, '*.jpg'))
print(f"Train Data: {len(train_list)}")
print(f"Test Data: {len(test_list)}")
# Out:
# Train Data: 25000
# Test Data: 12500

# %%
labels = [path.split('/')[-1].split('.')[0] for path in train_list]   #ground truth

# %% [markdown]
# ## Plot random image with their label

# %%
random_idx = np.random.randint(1, len(train_list), size=9)
fig, axes = plt.subplots(3, 3, figsize=(16, 12))

for idx, ax in enumerate(axes.ravel()):
    img = Image.open(train_list[idx])
    ax.set_title(labels[idx])
    ax.imshow(img)

# %% [markdown]
# ## Use Sklearn to split the training data

# %%
train_list, valid_list = train_test_split(train_list, 
                                          test_size=0.2,
                                          stratify=labels,
                                          random_state=0)

# %%
print(f"Train Data: {len(train_list)}")
print(f"Validation Data: {len(valid_list)}")
print(f"Test Data: {len(test_list)}")
# Out:
# Train Data: 20000
# Validation Data: 5000
# Test Data: 12500

# %%
print(train_list[0])
print(test_list[0])
# Out:
# train/dog.2988.jpg
# test/6813.jpg

# %% [markdown]
# We will discuss this in more detail in a near future...

# %%
train_transforms = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(degrees=15),
    transforms.ToTensor(),
])

test_transforms = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
])

# %% [markdown]
# Define the dataset using PIL to read image

# %%
class CatsDogsDataset(Dataset):
    def __init__(self, file_list, transform=None):
        self.file_list = file_list
        self.transform = transform
        self.filelength = len(file_list)

    def __len__(self):
        return self.filelength

    def __getitem__(self, idx):
        img_path = self.file_list[idx]
        img = Image.open(img_path)
        img_transformed = self.transform(img)
        label = img_path.split("/")[-1].split(".")[0]
        label = 1 if label == "dog" else 0
        return img_transformed, label

# %%
train_data = CatsDogsDataset(train_list, transform=train_transforms)
valid_data = CatsDogsDataset(valid_list, transform=test_transforms)
test_data = CatsDogsDataset(test_list, transform=test_transforms)

# %% [markdown]
# Let's see what is the size of an image from the dataset

# %%
print(train_data[0][0].shape)
# Out:
# torch.Size([3, 128, 128])

# %% [markdown]
# Create dataloader, you can modify the batch size if needed

# %%
batch_size = 32
wandb.log({'batch_size': batch_size})
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(dataset=valid_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

# %%
from torch.nn import Module
from torch.nn import Conv2d
from torch.nn import Linear
from torch.nn import MaxPool2d
from torch.nn import ReLU
from torch.nn import LogSoftmax
from torch.nn import Dropout
from torch import flatten

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3,20,kernel_size=(5,5), padding=1,stride=1),  #3 input channels, 20 out channels
            #nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2)),
            #nn.Dropout(0.2)
        )
        
        self.layer2 = nn.Sequential(
            nn.Conv2d(in_channels=20, out_channels=50, kernel_size=(5,5)),
            #nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2)),
            #nn.Dropout(0.2)
            )
        
        #self.layer3 = nn.Sequential(
        #    nn.Conv2d(64,128, kernel_size=3, padding=0, stride=1),
        #    nn.BatchNorm2d(128),
        #    nn.ReLU(),
        #    nn.MaxPool2d(2),
        #    nn.Dropout(0.2)
        #)
        
        #self.layer4 = nn.Sequential(
        #    nn.Conv2d(128,256, kernel_size=3, padding=0, stride=1),
        #    nn.BatchNorm2d(256),
        #    nn.ReLU(),
        #    nn.MaxPool2d(2),
        #    nn.Dropout(0.2)
        #)
        
        
        #self.fc1 = nn.Linear(25600,512)
        self.fc1 = nn.Linear(in_features=42050, out_features=500)
        self.relu = nn.ReLU()
        #self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(in_features=500, out_features=2)
        
        
    def forward(self,x):
        out = self.layer1(x)
        out = self.layer2(out)
        #out = self.layer3(out)
        #out = self.layer4(out)
        out = out.view(out.size(0),-1)
        out = self.relu(self.fc1(out))
        out = self.fc2(out)
        return out

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = Net().to(device)
net.train()
# Out:
# Net(
#   (layer1): Sequential(
#     (0): Conv2d(3, 20, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(20, 50, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Linear(in_features=42050, out_features=500, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=500, out_features=2, bias=True)
# )

# %%
lr = 0.01

o = 's'

if o == 's':
    optimizer = torch.optim.SGD(net.parameters(), lr=lr)
    wandb.log({'optimizer':'SGD'})
elif o == 'a':
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)
    wandb.log({'optimizer':'Adam'})

wandb.log({'lr': lr})
criterion = nn.CrossEntropyLoss()

epochs = 15
wandb.log({'epochs': epochs})

for epoch in range(epochs):
    epoch_loss = 0
    epoch_accuracy = 0
    
    train_losses = []
    train_acc = []
    valid_losses = []
    valid_acc = []
    
    for data, label in train_loader:
        data = data.to(device)
        label = label.to(device)
        
        output = net(data)
        loss = criterion(output, label)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        acc = ((output.argmax(dim=1) == label).float().mean())
        epoch_accuracy += acc/len(train_loader)
        epoch_loss += loss/len(train_loader)
        train_losses.append(epoch_loss)
        train_acc.append(epoch_accuracy)
        
    print('Epoch : {}, train accuracy : {}, train loss : {}'.format(epoch+1, epoch_accuracy,epoch_loss))
    
    
    with torch.no_grad():
        epoch_val_accuracy=0
        epoch_val_loss =0
        for data, label in valid_loader:
            data = data.to(device)
            label = label.to(device)
            
            val_output = net(data)
            val_loss = criterion(val_output,label)
            
            
            acc = ((val_output.argmax(dim=1) == label).float().mean())
            epoch_val_accuracy += acc/ len(valid_loader)
            epoch_val_loss += val_loss/ len(valid_loader)
            valid_losses.append(epoch_val_loss)
            valid_acc.append(epoch_val_accuracy)
            
        print('Epoch : {}, val_accuracy : {}, val_loss : {}'.format(epoch+1, epoch_val_accuracy,epoch_val_loss))
        
wandb.log({'train_loss':train_losses[-1]})
wandb.log({'val_loss':valid_losses[-1]})
wandb.log({'val_accuracy':valid_acc[-1]})
wandb.log({'train_accuracy':train_acc[-1]})
# Out:
# Epoch : 1, train accuracy : 0.5520997643470764, train loss : 0.6844865083694458
# Epoch : 1, val_accuracy : 0.5957404375076294, val_loss : 0.6712052822113037
# Epoch : 2, train accuracy : 0.6042993664741516, train loss : 0.6635234951972961
# Epoch : 2, val_accuracy : 0.6299760341644287, val_loss : 0.6443613767623901
# Epoch : 3, train accuracy : 0.6448999643325806, train loss : 0.6339760422706604
# Epoch : 5, train accuracy : 0.7035504579544067, train loss : 0.5735199451446533
# Epoch : 5, val_accuracy : 0.6910828948020935, val_loss : 0.5823040008544922
# Epoch : 6, train accuracy : 0.7166004180908203, train loss : 0.5547095537185669
# Epoch : 6, val_accuracy : 0.7159636616706848, val_loss : 0.5493390560150146
# Epoch : 7, train accuracy : 0.7287512421607971, train loss : 0.5378846526145935
# Epoch : 7, val_accuracy : 0.7181529402732849, val_loss : 0.5466251969337463
# Epoch : 9, train accuracy : 0.7555505037307739, train loss : 0.5032880306243896
# Epoch : 9, val_accuracy : 0.7484079599380493, val_loss : 0.5179144144058228
# Epoch : 10, train accuracy : 0.7637503743171692, train loss : 0.4876822829246521
# Epoch : 10, val_accuracy : 0.7655255794525146, val_loss : 0.49337100982666016
# Epoch : 11, train accuracy : 0.7774001359939575, train loss : 0.4673794209957123

# %%
dog_probs = []
net.eval()
i=0
with torch.no_grad():
    for data, _ in test_loader:
        data = data.to(device)
        preds = net(data)
        preds_list = F.softmax(preds, dim=1)[:, 1].tolist()
        dog_probs += list(zip(list(range(1+i,batch_size+1+i)), preds_list))
        #print(preds_list)
        i += batch_size
        
#dog_probs.sort(key = lambda x : int(x[0]))
#print(dog_probs[1])

idx = list(map(lambda x: x[0],dog_probs))
prob = list(map(lambda x: x[1],dog_probs))
for i in range(1,len(dog_probs)):
    submission = pd.DataFrame({'id':idx,'label':prob})
submission.to_csv('submission.csv',index=False)
